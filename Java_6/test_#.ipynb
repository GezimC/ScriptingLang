# %%
import LogAnalyzer as la

# %%
logins = la.load_dataset("suspicious_logins.json")

# %%
la.detect_bruteforce(events=logins, threshold=4, window_seconds=60)
# Out:
# alice --> Potential brute force
# carol --> Potential brute force
