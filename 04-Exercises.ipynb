# %% [markdown]
# # Python Tuples, Dictionaries, and Functions Exercises
#
# Practice problems covering **tuples, dictionaries, and functions**.

# %% [markdown]
# ## Exercise 1
#
# **Request:**
#
# Create a tuple with 4 values and print the first and last element.

# %%
packet = ("192.168.1.10", "192.168.1.20", 443, "TCP")

# %% [markdown]
# ## Exercise 2
#
# **Request:**
#
# Create a tuple of 3 open ports and print each port using a loop.

# %%
open_ports = (22, 80, 443)

# %% [markdown]
# ## Exercise 3
#
# **Request:**
#
# Create a dictionary for one student with keys: `name`, `age`, and `city`. Print each value.

# %% [markdown]
# ## Exercise 4
#
# **Request:**
#
# Given a dictionary of services and ports, print the service name and its port.

# %%
services = {
    "SSH": 22,
    "HTTP": 80,
    "HTTPS": 443,
    "DNS": 53
}

# %% [markdown]
# ## Exercise 5
#
# **Request:**
#
# Given a dictionary of failed login attempts per user, find which user has the highest number of failed attempts.

# %%
failed_logins = {
    "admin": 5,
    "student1": 2,
    "guest": 7,
    "teacher": 3
}

# %% [markdown]
# ## Exercise 6
#
# **Request:**
#
# Count how many IP addresses in a dictionary are marked as suspicious (`True`).

# %%
suspicious_ips = {
    "192.168.1.10": False,
    "10.0.0.5": True,
    "172.16.0.8": True,
    "192.168.1.15": False
}

# %% [markdown]
# ## Exercise 7
#
# **Request:**
#
# Create a function `greet_user(name)` that prints a greeting message.

# %% [markdown]
# ## Exercise 8
#
# **Request:**
#
# Create a function `is_even(number)` that returns `True` if a number is even, otherwise `False`.

# %% [markdown]
# ## Exercise 9
#
# **Request:**
#
# Create a function `check_port(port)` that prints whether a port is well-known (less than 1024) or not.

# %% [markdown]
# ## Exercise 10
#
# **Request:**
#
# Create a function `count_failed_attempts(attempts)` that takes a list like `[True, False, True]` where `True` means failed login, and returns how many failed attempts there are.

# %% [markdown]
# ## Exercise 1 — Suspicious Login Attempts
#
# Create a function `check_attempts(username, attempts, max_allowed)`.
#
# The function should:
#
# - receive a username
# - receive number of login attempts
# - receive maximum allowed attempts
#
# If attempts exceed the limit, print:
#
# `Access blocked for <username>`
#
# Otherwise print:
#
# `Access allowed for <username>`

# %% [markdown]
# ## Exercise 12 — Calculate Network Packet Size
#
# Create a function `packet_size(data_size, header_size, encryption_overhead)`.
#
# The function should return the **total packet size**.

# %% [markdown]
# ## Example — Functions with Arbitrary Parameters (*args)
#
# Sometimes we do not know how many parameters will be passed to a function.
#
# Using `*args` allows the function to accept multiple values.

# %%
# sum of numbers

# %% [markdown]
# ## Cybersecurity Example — Port Scanner Simulation (*args)
#
# Create a function that receives multiple ports and prints them as scanned ports.

# %% [markdown]
# ## Example — Keyword Arguments (**kwargs)
#
# `**kwargs` allows a function to receive named parameters.

# %%
# show user info username, role etc

# %% [markdown]
# ## Cybersecurity Example — Log Event (**kwargs)
#
# Create a function that prints security log information such as IP address, action, and status.
